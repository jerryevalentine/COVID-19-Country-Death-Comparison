# %%
#Increate the size of cells
from IPython.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))

# %%
import pandas as pd
import seaborn as sns
from scipy.stats import kurtosis
from scipy.stats import skew
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
worldometer_data_Deaths_NA = Path("worldometer_data_Deaths_NA.csv")

# Import the data into a Pandas DataFrame
worldometer_data_Deaths_NA = pd.read_csv(worldometer_data_Deaths_NA, encoding="UTF-8")
worldometer_data_Deaths_NA.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Country_Region      Continent    Population  \
# 0             0           0            USA  North America  3.311981e+08
# 1             1           1         Brazil  South America  2.127107e+08
# 2             2           2          India           Asia  1.381345e+09
# 3             3           3         Russia         Europe  1.459409e+08
# 4             4           4   South Africa         Africa  5.938157e+07
#
#    TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  \
# 0     5032179       NaN     162804.0        NaN       2576668.0           NaN
# 1     2917562       NaN      98644.0        NaN       2047660.0           NaN
# 2     2025409       NaN      41638.0        NaN       1377384.0           NaN
# 3      871894       NaN      14606.0        NaN        676357.0           NaN
# 4      538184       NaN       9604.0        NaN        387316.0           NaN
#
# ...

# %%
country_wise_latest = Path("country_wise_latest.csv")

# Import the data into a Pandas DataFrame
country_wise_latest = pd.read_csv(country_wise_latest, encoding="UTF-8")
country_wise_latest.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %% [markdown]
# Final Project
#
# Now it is your turn to tell me something interesting. Select any dataset on Kaggle (https://www.kaggle.com ). Use various concepts learned in this class to explore, draw conclusions and/or build a model around the selected dataset The main thing is to learn and to have fun doing it, so select a dataset that interests you. Please note the final project makes up 15% of your final grade.
#
# Due: Jun 4, 2023, 11:59 PM
#
#
# Use various concepts learned in this class. Including but not limited to:
#
# data preprocessing
# data cleaning
# MS Excel
# UNIX CLI
# visualization charts
# machine-learning modeling
#
# The total time spent on the project - including research, design, configuring, coding, testing, redesign, etc., should be around 10 -  15 hours.
#
#
# Submit:
#
# 2-3 page written report detailing the project.
# Include Juypter Notebook in the appendix
#
# Data comes from: https://www.kaggle.com/datasets/imdevskp/corona-virus-report
#
# *Summary of Data*
# <ul>
#    <li>full_grouped.csv - Day to day country wise no. of cases (Has County/State/Province level data)</li>
#    <li>covid_19_clean_complete.csv - Day to day country wise no. of cases (Doesn't have County/State/Province level data)</li>
#    <li>country_wise_latest.csv - Latest country level no. of cases</li>
#    <li>day_wise.csv - Day wise no. of cases (Doesn't have country level data)</li>
#    <li>usa_county_wise.csv - Day to day county level no. of cases</li>
#    <li>worldometer_data.csv - Latest data from https://www.worldometers.info/</li>
# </ul>

# %% [markdown]
# #Load Data
# #Since the most important item is to examine how well the United States did, or did not do, during the pandemic, world data by country is the best.
# worldometer_data.to_csv('./worldometer_data.csv')
#
# #####data preprocessing
# #worldometer_data.rename(columns = {"Deaths/1M pop":'Deaths_Per_Million'}, inplace = True)
# #worldometer_data.rename(columns = {"Country/Region":'Country_Region'}, inplace = True)
#
# #worldometer_data.head()
# #worldometer_data=worldometer_data.dropna(subset=['Deaths_Per_Million'])
# worldometer_data.head()
#
#
# worldometer_data.to_csv('./worldometer_data_Deaths_NA.csv')
#
# worldometer_data[["Deaths_Per_Million"]].median()
# #Mean - 99
# #median - 92
#
# #Density plot of "Deaths/1M pop"
# ##Mean and Median "Deaths/1M pop"
# #Mean - 99
# #median - 92
# #sns.set_style('darkgrid')
# #3.1 - deaths.skew()
# #123.4 - deaths.kurtosis()
# deaths = worldometer_data_Deaths_NA["Deaths_Per_Million"]
# sns.distplot(deaths)
#
#
# ***Summary Data United States***
# <ul>
#    <li>Most of the analysis is done with the worldometer_data.csv dataset, but there are five others.</li>
#    <li>The dataset is from August 2020</li>
#    <li>United States - Total Deaths</li>
#         <ul>
#            <li>1,130,593 (6/4/2023)
#            <li>Total in this dataset: 162,804 (6/2020)
#         </ul>
# </ul>
#
#
# ***Worldwide Mean and Median "Deaths/1M pop" (6/2020)***
# <ul>
#     <li>Mean - 99</li>
#     <li>median - 92</li>
# </ul>
#
# ***Country and Death_Pop_Ratio_Per_Millions***
# <ul>
#    <li>Belgium	     850 (see first citation)</li>
#    <li>UK           683(see second citation)</li>
#    <li>Peru         619</li>
#    <li>Spain	     610</li>
#    <li>Italy	     582</li>
#    <li>Chile        517</li>
#    <li>USA          492</li>
#    <li>Brazil       464</li>
#    <li>Mexico	     391</li>
#    <li>Canada	     237</li>
#    <li>Japan        8</li>
#    <li>South Korea  8</li>
# </ul>
#
# ***Not just counting deaths in hospitals and care homes, but including deaths in care homes that are suspected, not confirmed, as Covid-19 cases.  https://www.bbc.com/news/world-europe-52491210**
#
# ****A piece in the guradian suggested that recommendations that masks were not needed in care home significantly increased the death toll https://www.theguardian.com/world/2021/jan/26/why-has-britain-suffered-more-than-100000-covid-deaths**
#
#
# ***Continent - average deaths per million people***
# <ul>
#    <li>Australia/Oceania	   4.0</li>
#    <li>Africa	               18</li>
#    <li>Asia	                   44</li>
#    <li>North America	       111</li>
#    <li>Europe	               215</li>
#    <li>South America	       217</li>
# </ul>

# %%
#sns.set_style('darkgrid')
#3.1 - deaths.skew()
#123.4 - deaths.kurtosis()
deaths = worldometer_data_Deaths_NA["Deaths_Per_Million"]
worldometer_data=worldometer_data_Deaths_NA.dropna(subset=['Deaths_Per_Million'])
sns.distplot(deaths)
# Out:
# C:\Users\jerry\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Deaths_Per_Million', ylabel='Density'>

# %%
countinet_average_deaths = worldometer_data.groupby(['Continent'])['Deaths_Per_Million'].mean()
countinet_average_deaths = countinet_average_deaths.to_frame(name="Deaths_Per_Million")
countinet_average_deaths
# Out:
#                    Deaths_Per_Million
# Continent
# Africa                      18.241455
# Asia                        43.971429
# Australia/Oceania            3.825000
# Europe                     214.955556
# North America              110.607143
# South America              216.769231

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
#This section allows for the comparison of the death rate between different countries.
#The one that will be compared to a second country.
country_name_1 = 'USA'

#This is the country that will be compared to country 1.  Specifically, the death rate
#of country 2 will be used to determine how many people in country 1 would have died if
#country 1 had the same number of deaths, per million, as country 2.
country_name_2 = 'Belgium'

Deaths_Per_Million_country_name_1 = worldometer_data[worldometer_data['Country_Region']==country_name_1]['Deaths_Per_Million'].iloc[0]
Deaths_Per_Million_country_name_2 = worldometer_data[worldometer_data['Country_Region']==country_name_2]['Deaths_Per_Million'].iloc[0]
Total_Deaths_country_name_1 = round(worldometer_data[worldometer_data['Country_Region']==country_name_1]['TotalDeaths'].iloc[0])

#This is the population of country 1 in millions.
millions_pop_country_name_1 = worldometer_data[worldometer_data['Country_Region']==country_name_1]['Population'].iloc[0]/1000000

#This is the population of country 1 in millions.
population_country_name_1 = worldometer_data[worldometer_data['Country_Region']==country_name_1]['Population'].iloc[0]

print('*************Country 1 deaths per million and totoal populoation ******')
print(country_name_1, ": Deaths Per Million Country 1 - ", round(Deaths_Per_Million_country_name_1))
print(country_name_2, ": Deaths Per Million Country 2 - ", round(Deaths_Per_Million_country_name_2))
print(country_name_1, ": Population  - ", '{:,}'.format(population_country_name_1))

country_1_deaths_million_1 = '{:,}'.format(round(millions_pop_country_name_1*Deaths_Per_Million_country_name_1))
country_1_deaths_million_2 = '{:,}'.format(round(millions_pop_country_name_1*Deaths_Per_Million_country_name_2))

print("Deaths per million using ", country_name_1 , "'s' death per million: ", country_1_deaths_million_1)

print("Deaths per million using ", country_name_2 , "'s' death per million: ", country_1_deaths_million_2)

predicted_lost = round(millions_pop_country_name_1*Deaths_Per_Million_country_name_2)

print("If ", country_name_1, " had the same death rate as " , country_name_2, ", then ", country_name_1, " would have lost ", '{:,}'.format(predicted_lost) , " people, instead of ", '{:,}'.format(Total_Deaths_country_name_1))

country_1_Mean_Deaths = '{:,}'.format(round(millions_pop_country_name_1*99))

print("If ", country_name_1, " had an average death rate of 99 per million people, it would have lost ", country_1_Mean_Deaths, "people instead of ", country_1_deaths_million_1)
# Out:
# *************Country 1 deaths per million and totoal populoation ******
# USA : Deaths Per Million Country 1 -  492
# Belgium : Deaths Per Million Country 2 -  850
# USA : Population  -  331,198,130.0
# Deaths per million using  USA 's' death per million:  162,949
# Deaths per million using  Belgium 's' death per million:  281,518
# If  USA  had the same death rate as  Belgium , then  USA  would have lost  281,518  people, instead of  162,804
# If  USA  had an average death rate of 99 per million people, it would have lost  32,789 people instead of  162,949

# %%
#country_wise_latest#Latest country level no. of cases

#day_wise#Day wise no. of cases (Doesn't have country level data)

#usa_county_wise#Day to day county level no. of cases

#worldometer_data#Latest data from https://www.worldometers.info/
#worldometer_data['Death_Pop_Ratio_Per_Millions'] = 0
#rng = len(worldometer_data) - 1
#for i in range(rng):
#    worldometer_data.loc[i, 'Death_Pop_Ratio_Per_Millions'] = float((worldometer_data.loc[i, 'TotalDeaths']/worldometer_data.loc[i, 'Population'])*1000000)
#worldometer_data.sort_values(by=['Deaths/1M pop'])
#worldometer_data_Deaths_NA = worldometer_data.dropna(subset=['TotalDeaths'], how='all')
worldometer_data_Deaths_NA.sort_values(by=['Deaths_Per_Million'], ascending=True)
# Out:
#      Unnamed: 0.1  Unnamed: 0         Country_Region          Continent  \
# 164           164         164                Burundi             Africa
# 139           139         139                 Uganda             Africa
# 165           165         165                Myanmar               Asia
# 154           154         154                Vietnam               Asia
# 178           178         178       Papua New Guinea  Australia/Oceania
# ..            ...         ...                    ...                ...
# 202           202         202  Saint Kitts and Nevis      North America
# 203           203         203              Greenland      North America
# 205           205         205  Caribbean Netherlands      North America
# 206           206         206       Falkland Islands      South America
# 207           207         207           Vatican City             Europe
#
#      Population  TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# ...

# %%
# Importing Pandas to create DataFrame
import pandas as pd
#full_grouped
csvImport  = 'full_grouped.csv'
full_grouped = pd.read_csv(csvImport)

#covid_19_clean_complete
csvImport = 'covid_19_clean_complete.csv'
covid_19_clean_complete = pd.read_csv(csvImport)

#country_wise_latest
csvImport = 'country_wise_latest.csv'
country_wise_latest = pd.read_csv(csvImport)

#day_wise
csvImport = 'day_wise.csv'
day_wise = pd.read_csv(csvImport)

#usa_county_wise
csvImport = 'usa_county_wise.csv'
usa_county_wise = pd.read_csv(csvImport)

#worldometer_data
csvImport = 'worldometer_data.csv'
worldometer_data = pd.read_csv(csvImport)

# %%
covid_19_clean_complete.head()#Day to day country wise no. of cases (Doesn't have County/State/Province level data)
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
full_grouped.head()#Day to day country wise no. of cases (Has County/State/Province level data)
# Out:
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
# 1  2020-01-22        Albania          0       0          0       0          0
# 2  2020-01-22        Algeria          0       0          0       0          0
# 3  2020-01-22        Andorra          0       0          0       0          0
# 4  2020-01-22         Angola          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region
# 0           0              0  Eastern Mediterranean
# 1           0              0                 Europe
# 2           0              0                 Africa
# 3           0              0                 Europe
# 4           0              0                 Africa
